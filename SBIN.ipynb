# %%
import pandas as pd
import numpy as np
import yfinance as yf

# %%
sbin = yf.Ticker('SBIN.NS')

# %%
sbin_1m = sbin.history(period='1mo')

# %%
sbin_1m = sbin_1m[['Close']]

# %%
sbin_1m.index = pd.to_datetime(sbin_1m.index).date

# %%
sbin_1m.plot(figsize=[20,5])
# Out:
# <Axes: >
